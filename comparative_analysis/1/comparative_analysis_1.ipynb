# %% [markdown]
# # Comparative Analysis 1
#
# We compared the image processing steps in workflows created using the base visual programming language for image processing (VPL4IP) and the one enhanced by our im2im library. We also assessed the technical demands on users for building such workflows. Both VPL4IPS are built on Blockly.

# %%
# !git clone https://github.com/c3di/im2im.git

import base64
from IPython.display import IFrame, display

def display_html(html_file_path, width=1200, height=900):
  with open(html_file_path, 'r') as file:
      html_content = file.read()

  html_base64 = base64.b64encode(html_content.encode()).decode()
  data_uri = f"data:text/html;base64,{html_base64}"
  display(IFrame(data_uri, width, height))

# !cp "im2im/evaluation/comparative_analysis_1/retinal.jpg" "retinal.jpg"
# Out:
# Cloning into 'im2im'...
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Base VPL4IP
#
# the source file for base VPL4IP created using Blockly is located at "im2im/evaluation/comparative_analysis_1/base_VPL4IP.html"

# %%
html_file_path = 'im2im/evaluation/comparative_analysis_1/base_VPL4IP.html'
display_html(html_file_path, 1700, 1000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 html_file_path = 'im2im/evaluation/case_1/base_VPL4IP.html'
# ----> 2 display_html(html_file_path, 1700, 1000)
#
# Cell In[2], line 7, in display_html(html_file_path, width, height)
#       6 def display_html(html_file_path, width=1200, height=900):
# ----> 7   with open(html_file_path, 'r') as file:
#       8       html_content = file.read()
#      10   html_base64 = base64.b64encode(html_content.encode()).decode()
#
# File ~\AppData\Local\anaconda3\envs\chaldene\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
# ...

# %% [markdown]
# **Textual Code generated from the Workflow**
#
# The textual code below is generated from the workflow in the base VPL4IP and is run to demonstrate that the workflows function correctly.

# %%
import matplotlib.pyplot as plt
from PIL import Image
from skimage.util import img_as_ubyte
from skimage.color import gray2rgb
from skimage.filters import sato
import cv2
from PIL import ImageDraw

denoised_image = cv2.fastNlMeansDenoisingColored(cv2.imread('retinal.jpg'), None, 10, 10, 7, 21)

sato_filtered_image = sato(cv2.cvtColor(denoised_image, cv2.COLOR_BGR2GRAY), sigmas=range(1, 10, 2), black_ridges=True)

uint8_image = gray2rgb(sato_filtered_image)

pil_image = Image.fromarray(img_as_ubyte(uint8_image / uint8_image.max()))
draw = ImageDraw.Draw(pil_image)
draw.ellipse([(210 - 160, 650 - 160), (210 + 160, 650 + 160)], outline='red', width=10)

# %% [markdown]
# **Results Inspection**

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
ax[0].imshow(denoised_image[:,:,::-1])
ax[0].set_title('After denoising')
ax[0].axis('off')

ax[1].imshow(sato_filtered_image, cmap='gray')
ax[1].set_title('After Sato Filter')
ax[1].axis('off')

ax[2].imshow(pil_image)
ax[2].set_title('Annotated Image')
ax[2].axis('off')

plt.show()

# %% [markdown]
# ## Enhanced VPL4IP by our im2im library
#
# the source file for enhanced VPL4IP created using Blockly is located at "im2im/evaluation/comparative_analysis_1/enhanced_VPL4IP.html"

# %%
html_file_path = 'im2im/evaluation/comparative_analysis_1/enhanced_VPL4IP.html'
display_html(html_file_path, 1700, 1000)

# %% [markdown]
# **Textual Code generated from the Workflow**
#
# The textual code below is generated from the workflow in the base VPL4IP and is run to demonstrate that the workflows function correctly.

# %% [markdown]
# **Results Inspection**

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 6))
ax[0].imshow(denoised_image[:,:,::-1])
ax[0].set_title('After denoising')
ax[0].axis('off')

ax[1].imshow(sato_filtered_image, cmap='gray')
ax[1].set_title('After Sato Filter')
ax[1].axis('off')

ax[2].imshow(pil_image)
ax[2].set_title('Annotated Image')
ax[2].axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fig, ax = plt.subplots(1, 3, figsize=(18, 6))
#       2 ax[0].imshow(denoised_image[:,:,::-1])
#       3 ax[0].set_title('After denoising')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Error Measurement

# %%
# bla bla

# %% [markdown]
# ## Discussion
# bla,bla
